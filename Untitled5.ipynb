# %%
import math
import random
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset
from transformers import AutoTokenizer
from sklearn.model_selection import KFold

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print("Using device:", device)
print("PyTorch version:", torch.__version__)
# Out:
# Using device: cpu
# PyTorch version: 2.11.0+cpu

# %%
raw_dataset = load_dataset("Helsinki-NLP/opus_books", "en-fr")

print(raw_dataset)
print(raw_dataset["train"][0])
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# en-fr/train-00000-of-00001.parquet:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/127085 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 127085
#     })
# })
# {'id': '0', 'translation': {'en': 'The Wanderer', 'fr': 'Le grand Meaulnes'}}

# %%
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-fr")

pad_token_id = tokenizer.pad_token_id
eos_token_id = tokenizer.eos_token_id

print("Vocabulary size:", len(tokenizer))
print("PAD token ID:", pad_token_id)
print("EOS token ID:", eos_token_id)
# Out:
# config.json:   0%|          | 0.00/1.42k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# Vocabulary size: 59514
# PAD token ID: 59513
# EOS token ID: 0
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
# Dataset settings
use_full_dataset_for_kfold = False

# For K-Fold, start with 20000 or 40000.
# Full dataset K-Fold can be very slow.
subset_size = 20000

k_folds = 5

# Early stopping settings
max_epochs = 20
patience = 3
min_delta = 0.01

# Training settings
batch_size = 64
max_seq_length = 64
learning_rate = 0.0003

# Transformer settings
d_model = 256
num_heads = 4
num_layers = 3
d_ff = 512
dropout = 0.1

# Reproducibility
seed = 42

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)

if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# %%
if use_full_dataset_for_kfold:
    small_dataset = raw_dataset["train"].shuffle(seed=seed)
else:
    small_dataset = raw_dataset["train"].shuffle(seed=seed).select(range(subset_size))

print("Dataset size used for K-Fold:", len(small_dataset))
print(small_dataset[0])
# Out:
# Dataset size used for K-Fold: 20000
# {'id': '44126', 'translation': {'en': '"Not if it were my own brother!" cried d’Artagnan, as if carried away by his enthusiasm.', 'fr': "«Non, fût-ce mon frère!» s'écria d'Artagnan comme emporté par l'enthousiasme."}}

# %%
class TranslationDataset(Dataset):
    def __init__(self, dataset, tokenizer, max_length=64):
        self.dataset = dataset
        self.tokenizer = tokenizer
        self.max_length = max_length

        self.pad_token_id = tokenizer.pad_token_id
        self.eos_token_id = tokenizer.eos_token_id

    def __len__(self):
        return len(self.dataset)

    def encode_source(self, text):
        encoding = self.tokenizer(
            text,
            max_length=self.max_length,
            padding="max_length",
            truncation=True,
            return_tensors="pt"
        )

        return encoding["input_ids"].squeeze(0)

    def encode_target_with_start_token(self, text):
        # Tokenize target without padding first
        encoding = self.tokenizer(
            text,
            max_length=self.max_length - 1,
            padding=False,
            truncation=True,
            return_tensors=None
        )

        target_ids = encoding["input_ids"]

        # Add decoder start token at the beginning
        target_ids = [self.pad_token_id] + target_ids

        # Pad manually to max_length
        if len(target_ids) < self.max_length:
            target_ids = target_ids + [self.pad_token_id] * (self.max_length - len(target_ids))
        else:
            target_ids = target_ids[:self.max_length]

        return torch.tensor(target_ids, dtype=torch.long)

    def __getitem__(self, idx):
        example = self.dataset[idx]["translation"]

        src_text = example["en"]
        tgt_text = example["fr"]

        src_ids = self.encode_source(src_text)
        tgt_ids = self.encode_target_with_start_token(tgt_text)

        return {
            "src_ids": src_ids,
            "tgt_ids": tgt_ids,
            "src_text": src_text,
            "tgt_text": tgt_text
        }

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()

        assert d_model % num_heads == 0, "d_model must be divisible by num_heads"

        self.d_model = d_model
        self.num_heads = num_heads
        self.d_k = d_model // num_heads

        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)

    def split_heads(self, x):
        batch_size, seq_length, d_model = x.size()

        x = x.view(batch_size, seq_length, self.num_heads, self.d_k)

        return x.transpose(1, 2)

    def combine_heads(self, x):
        batch_size, num_heads, seq_length, d_k = x.size()

        x = x.transpose(1, 2).contiguous()

        return x.view(batch_size, seq_length, self.d_model)

    def scaled_dot_product_attention(self, Q, K, V, mask=None):
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)

        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)

        attention_weights = torch.softmax(scores, dim=-1)

        output = torch.matmul(attention_weights, V)

        return output

    def forward(self, Q, K, V, mask=None):
        Q = self.split_heads(self.W_q(Q))
        K = self.split_heads(self.W_k(K))
        V = self.split_heads(self.W_v(V))

        attention_output = self.scaled_dot_product_attention(Q, K, V, mask)

        output = self.W_o(self.combine_heads(attention_output))

        return output

# %%
class PositionWiseFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super().__init__()

        self.fc1 = nn.Linear(d_model, d_ff)
        self.fc2 = nn.Linear(d_ff, d_model)
        self.relu = nn.ReLU()

    def forward(self, x):
        return self.fc2(self.relu(self.fc1(x)))

# %%
class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_seq_length):
        super().__init__()

        pe = torch.zeros(max_seq_length, d_model)

        position = torch.arange(
            0,
            max_seq_length,
            dtype=torch.float
        ).unsqueeze(1)

        div_term = torch.exp(
            torch.arange(0, d_model, 2).float()
            * (-math.log(10000.0) / d_model)
        )

        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)

        pe = pe.unsqueeze(0)

        self.register_buffer("pe", pe)

    def forward(self, x):
        seq_length = x.size(1)

        return x + self.pe[:, :seq_length, :]

# %%
class EncoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()

        self.self_attention = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)

        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, src_mask):
        attention_output = self.self_attention(x, x, x, src_mask)

        x = self.norm1(x + self.dropout(attention_output))

        ff_output = self.feed_forward(x)

        x = self.norm2(x + self.dropout(ff_output))

        return x

# %%
class DecoderLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout):
        super().__init__()

        self.self_attention = MultiHeadAttention(d_model, num_heads)
        self.cross_attention = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionWiseFeedForward(d_model, d_ff)

        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)

        self.dropout = nn.Dropout(dropout)

    def forward(self, x, encoder_output, src_mask, tgt_mask):
        self_attention_output = self.self_attention(x, x, x, tgt_mask)

        x = self.norm1(x + self.dropout(self_attention_output))

        cross_attention_output = self.cross_attention(
            x,
            encoder_output,
            encoder_output,
            src_mask
        )

        x = self.norm2(x + self.dropout(cross_attention_output))

        ff_output = self.feed_forward(x)

        x = self.norm3(x + self.dropout(ff_output))

        return x

# %%
class Transformer(nn.Module):
    def __init__(
        self,
        src_vocab_size,
        tgt_vocab_size,
        d_model,
        num_heads,
        num_layers,
        d_ff,
        max_seq_length,
        dropout,
        pad_token_id
    ):
        super().__init__()

        self.src_embedding = nn.Embedding(
            src_vocab_size,
            d_model,
            padding_idx=pad_token_id
        )

        self.tgt_embedding = nn.Embedding(
            tgt_vocab_size,
            d_model,
            padding_idx=pad_token_id
        )

        self.positional_encoding = PositionalEncoding(
            d_model,
            max_seq_length
        )

        self.encoder_layers = nn.ModuleList([
            EncoderLayer(d_model, num_heads, d_ff, dropout)
            for _ in range(num_layers)
        ])

        self.decoder_layers = nn.ModuleList([
            DecoderLayer(d_model, num_heads, d_ff, dropout)
            for _ in range(num_layers)
        ])

        self.fc_out = nn.Linear(d_model, tgt_vocab_size)

        self.dropout = nn.Dropout(dropout)

        self.pad_token_id = pad_token_id

    def generate_mask(self, src, tgt):
        src_mask = (src != self.pad_token_id).unsqueeze(1).unsqueeze(2)

        tgt_padding_mask = (tgt != self.pad_token_id).unsqueeze(1).unsqueeze(3)

        tgt_seq_length = tgt.size(1)

        nopeak_mask = torch.tril(
            torch.ones(
                1,
                1,
                tgt_seq_length,
                tgt_seq_length,
                device=tgt.device
            )
        ).bool()

        tgt_mask = tgt_padding_mask & nopeak_mask

        return src_mask, tgt_mask

    def forward(self, src, tgt):
        src_mask, tgt_mask = self.generate_mask(src, tgt)

        src_embedded = self.dropout(
            self.positional_encoding(self.src_embedding(src))
        )

        tgt_embedded = self.dropout(
            self.positional_encoding(self.tgt_embedding(tgt))
        )

        encoder_output = src_embedded

        for encoder_layer in self.encoder_layers:
            encoder_output = encoder_layer(encoder_output, src_mask)

        decoder_output = tgt_embedded

        for decoder_layer in self.decoder_layers:
            decoder_output = decoder_layer(
                decoder_output,
                encoder_output,
                src_mask,
                tgt_mask
            )

        output = self.fc_out(decoder_output)

        return output

# %%
def create_model():
    model = Transformer(
        src_vocab_size=len(tokenizer),
        tgt_vocab_size=len(tokenizer),
        d_model=d_model,
        num_heads=num_heads,
        num_layers=num_layers,
        d_ff=d_ff,
        max_seq_length=max_seq_length,
        dropout=dropout,
        pad_token_id=pad_token_id
    ).to(device)

    return model

# %%
def train_one_epoch(model, dataloader, optimizer, criterion, device):
    model.train()

    total_loss = 0

    for batch in dataloader:
        src = batch["src_ids"].to(device)
        tgt = batch["tgt_ids"].to(device)

        tgt_input = tgt[:, :-1]
        tgt_output = tgt[:, 1:]

        optimizer.zero_grad()

        predictions = model(src, tgt_input)

        loss = criterion(
            predictions.reshape(-1, predictions.size(-1)),
            tgt_output.reshape(-1)
        )

        loss.backward()

        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)

        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()

    total_loss = 0

    with torch.no_grad():
        for batch in dataloader:
            src = batch["src_ids"].to(device)
            tgt = batch["tgt_ids"].to(device)

            tgt_input = tgt[:, :-1]
            tgt_output = tgt[:, 1:]

            predictions = model(src, tgt_input)

            loss = criterion(
                predictions.reshape(-1, predictions.size(-1)),
                tgt_output.reshape(-1)
            )

            total_loss += loss.item()

    return total_loss / len(dataloader)

# %%
kf = KFold(
    n_splits=k_folds,
    shuffle=True,
    random_state=seed
)

indices = np.arange(len(small_dataset))

fold_results = []
fold_train_losses = []
fold_val_losses = []

for fold, (train_idx, val_idx) in enumerate(kf.split(indices)):
    print("=" * 80)
    print(f"Fold {fold + 1}/{k_folds}")
    print("=" * 80)

    train_subset = small_dataset.select(train_idx.tolist())
    val_subset = small_dataset.select(val_idx.tolist())

    print(f"Train examples: {len(train_subset)}")
    print(f"Val examples:   {len(val_subset)}")

    train_dataset = TranslationDataset(
        train_subset,
        tokenizer,
        max_length=max_seq_length
    )

    val_dataset = TranslationDataset(
        val_subset,
        tokenizer,
        max_length=max_seq_length
    )

    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True
    )

    val_loader = DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True
    )

    model = create_model()

    criterion = nn.CrossEntropyLoss(ignore_index=pad_token_id)

    optimizer = optim.Adam(
        model.parameters(),
        lr=learning_rate,
        betas=(0.9, 0.98),
        eps=1e-9
    )

    best_val_loss = float("inf")
    epochs_without_improvement = 0

    current_fold_train_losses = []
    current_fold_val_losses = []

    for epoch in range(max_epochs):
        train_loss = train_one_epoch(
            model,
            train_loader,
            optimizer,
            criterion,
            device
        )

        val_loss = evaluate(
            model,
            val_loader,
            criterion,
            device
        )

        current_fold_train_losses.append(train_loss)
        current_fold_val_losses.append(val_loss)

        print(f"Fold {fold + 1}, Epoch {epoch + 1}/{max_epochs}")
        print(f"Train Loss: {train_loss:.4f}")
        print(f"Val Loss:   {val_loss:.4f}")
        print("-" * 40)

        if val_loss < best_val_loss - min_delta:
            best_val_loss = val_loss
            epochs_without_improvement = 0

            torch.save(
                model.state_dict(),
                f"best_transformer_fold_{fold + 1}.pth"
            )

            print("Validation improved. Model saved.")
        else:
            epochs_without_improvement += 1
            print(
                f"No improvement for {epochs_without_improvement}/"
                f"{patience} epochs."
            )

        if epochs_without_improvement >= patience:
            print("Early stopping triggered.")
            break

    fold_results.append(best_val_loss)
    fold_train_losses.append(current_fold_train_losses)
    fold_val_losses.append(current_fold_val_losses)

    print(f"Best validation loss for fold {fold + 1}: {best_val_loss:.4f}")
# Out:
# ================================================================================
# Fold 1/5
# ================================================================================
# Train examples: 16000
# Val examples:   4000
# Fold 1, Epoch 1/30
# Train Loss: 6.0385
# Val Loss:   4.8004
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 2/30
# Train Loss: 4.4456
# Val Loss:   4.1619
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 3/30
# Train Loss: 3.9692
# Val Loss:   3.8571
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 4/30
# Train Loss: 3.6824
# Val Loss:   3.6559
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 5/30
# Train Loss: 3.4695
# Val Loss:   3.5161
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 6/30
# Train Loss: 3.2995
# Val Loss:   3.4128
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 7/30
# Train Loss: 3.1547
# Val Loss:   3.3192
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 8/30
# Train Loss: 3.0245
# Val Loss:   3.2353
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 9/30
# Train Loss: 2.9039
# Val Loss:   3.1702
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 10/30
# Train Loss: 2.7945
# Val Loss:   3.1220
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 11/30
# Train Loss: 2.6919
# Val Loss:   3.0752
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 12/30
# Train Loss: 2.5967
# Val Loss:   3.0211
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 13/30
# Train Loss: 2.5051
# Val Loss:   2.9831
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 14/30
# Train Loss: 2.4221
# Val Loss:   2.9660
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 15/30
# Train Loss: 2.3406
# Val Loss:   2.9422
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 16/30
# Train Loss: 2.2644
# Val Loss:   2.9226
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 17/30
# Train Loss: 2.1894
# Val Loss:   2.9019
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 18/30
# Train Loss: 2.1179
# Val Loss:   2.8822
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 19/30
# Train Loss: 2.0509
# Val Loss:   2.8712
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 20/30
# Train Loss: 1.9856
# Val Loss:   2.8523
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 21/30
# Train Loss: 1.9229
# Val Loss:   2.8478
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 1, Epoch 22/30
# Train Loss: 1.8606
# Val Loss:   2.8448
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 1, Epoch 23/30
# Train Loss: 1.8035
# Val Loss:   2.8408
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 24/30
# Train Loss: 1.7472
# Val Loss:   2.8225
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 25/30
# Train Loss: 1.6931
# Val Loss:   2.8332
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 1, Epoch 26/30
# Train Loss: 1.6445
# Val Loss:   2.8111
# ----------------------------------------
# Validation improved. Model saved.
# Fold 1, Epoch 27/30
# Train Loss: 1.5952
# Val Loss:   2.8193
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 1, Epoch 28/30
# Train Loss: 1.5442
# Val Loss:   2.8200
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 1, Epoch 29/30
# Train Loss: 1.5011
# Val Loss:   2.8110
# ----------------------------------------
# No improvement for 3/3 epochs.
# Early stopping triggered.
# Best validation loss for fold 1: 2.8111
# ================================================================================
# Fold 2/5
# ================================================================================
# Train examples: 16000
# Val examples:   4000
# Fold 2, Epoch 1/30
# Train Loss: 6.0588
# Val Loss:   4.7987
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 2/30
# Train Loss: 4.4494
# Val Loss:   4.1462
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 3/30
# Train Loss: 3.9691
# Val Loss:   3.8425
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 4/30
# Train Loss: 3.6876
# Val Loss:   3.6561
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 5/30
# Train Loss: 3.4837
# Val Loss:   3.5213
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 6/30
# Train Loss: 3.3190
# Val Loss:   3.4243
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 7/30
# Train Loss: 3.1781
# Val Loss:   3.3414
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 8/30
# Train Loss: 3.0533
# Val Loss:   3.2667
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 9/30
# Train Loss: 2.9405
# Val Loss:   3.2158
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 10/30
# Train Loss: 2.8372
# Val Loss:   3.1686
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 11/30
# Train Loss: 2.7451
# Val Loss:   3.1316
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 12/30
# Train Loss: 2.6548
# Val Loss:   3.1008
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 13/30
# Train Loss: 2.5714
# Val Loss:   3.0881
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 14/30
# Train Loss: 2.4926
# Val Loss:   3.0672
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 15/30
# Train Loss: 2.4193
# Val Loss:   3.0562
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 16/30
# Train Loss: 2.3463
# Val Loss:   3.0322
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 17/30
# Train Loss: 2.2780
# Val Loss:   3.0197
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 18/30
# Train Loss: 2.2104
# Val Loss:   3.0103
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 2, Epoch 19/30
# Train Loss: 2.1478
# Val Loss:   2.9995
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 20/30
# Train Loss: 2.0865
# Val Loss:   2.9940
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 2, Epoch 21/30
# Train Loss: 2.0290
# Val Loss:   2.9871
# ----------------------------------------
# Validation improved. Model saved.
# Fold 2, Epoch 22/30
# Train Loss: 1.9720
# Val Loss:   2.9901
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 2, Epoch 23/30
# Train Loss: 1.9171
# Val Loss:   2.9836
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 2, Epoch 24/30
# Train Loss: 1.8632
# Val Loss:   2.9876
# ----------------------------------------
# No improvement for 3/3 epochs.
# Early stopping triggered.
# Best validation loss for fold 2: 2.9871
# ================================================================================
# Fold 3/5
# ================================================================================
# Train examples: 16000
# Val examples:   4000
# Fold 3, Epoch 1/30
# Train Loss: 6.0634
# Val Loss:   4.7945
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 2/30
# Train Loss: 4.4728
# Val Loss:   4.1474
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 3/30
# Train Loss: 3.9941
# Val Loss:   3.8402
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 4/30
# Train Loss: 3.7105
# Val Loss:   3.6478
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 5/30
# Train Loss: 3.5043
# Val Loss:   3.5064
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 6/30
# Train Loss: 3.3360
# Val Loss:   3.4052
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 7/30
# Train Loss: 3.1942
# Val Loss:   3.3122
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 8/30
# Train Loss: 3.0663
# Val Loss:   3.2337
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 9/30
# Train Loss: 2.9521
# Val Loss:   3.1776
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 10/30
# Train Loss: 2.8504
# Val Loss:   3.1366
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 11/30
# Train Loss: 2.7565
# Val Loss:   3.0979
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 12/30
# Train Loss: 2.6672
# Val Loss:   3.0640
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 13/30
# Train Loss: 2.5838
# Val Loss:   3.0355
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 14/30
# Train Loss: 2.5035
# Val Loss:   3.0163
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 15/30
# Train Loss: 2.4280
# Val Loss:   2.9963
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 16/30
# Train Loss: 2.3543
# Val Loss:   2.9784
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 17/30
# Train Loss: 2.2845
# Val Loss:   2.9637
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 18/30
# Train Loss: 2.2194
# Val Loss:   2.9573
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 3, Epoch 19/30
# Train Loss: 2.1507
# Val Loss:   2.9550
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 3, Epoch 20/30
# Train Loss: 2.0894
# Val Loss:   2.9432
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 21/30
# Train Loss: 2.0309
# Val Loss:   2.9422
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 3, Epoch 22/30
# Train Loss: 1.9723
# Val Loss:   2.9284
# ----------------------------------------
# Validation improved. Model saved.
# Fold 3, Epoch 23/30
# Train Loss: 1.9168
# Val Loss:   2.9246
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 3, Epoch 24/30
# Train Loss: 1.8628
# Val Loss:   2.9313
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 3, Epoch 25/30
# Train Loss: 1.8112
# Val Loss:   2.9244
# ----------------------------------------
# No improvement for 3/3 epochs.
# Early stopping triggered.
# Best validation loss for fold 3: 2.9284
# ================================================================================
# Fold 4/5
# ================================================================================
# Train examples: 16000
# Val examples:   4000
# Fold 4, Epoch 1/30
# Train Loss: 6.0561
# Val Loss:   4.7712
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 2/30
# Train Loss: 4.4529
# Val Loss:   4.1277
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 3/30
# Train Loss: 3.9731
# Val Loss:   3.8225
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 4/30
# Train Loss: 3.6881
# Val Loss:   3.6337
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 5/30
# Train Loss: 3.4789
# Val Loss:   3.4948
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 6/30
# Train Loss: 3.3117
# Val Loss:   3.3882
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 7/30
# Train Loss: 3.1671
# Val Loss:   3.2978
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 8/30
# Train Loss: 3.0397
# Val Loss:   3.2297
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 9/30
# Train Loss: 2.9225
# Val Loss:   3.1659
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 10/30
# Train Loss: 2.8153
# Val Loss:   3.1219
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 11/30
# Train Loss: 2.7176
# Val Loss:   3.0734
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 12/30
# Train Loss: 2.6261
# Val Loss:   3.0346
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 13/30
# Train Loss: 2.5372
# Val Loss:   3.0083
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 14/30
# Train Loss: 2.4553
# Val Loss:   2.9868
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 15/30
# Train Loss: 2.3756
# Val Loss:   2.9559
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 16/30
# Train Loss: 2.3025
# Val Loss:   2.9356
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 17/30
# Train Loss: 2.2320
# Val Loss:   2.9212
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 18/30
# Train Loss: 2.1632
# Val Loss:   2.9058
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 19/30
# Train Loss: 2.0955
# Val Loss:   2.8966
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 4, Epoch 20/30
# Train Loss: 2.0325
# Val Loss:   2.9061
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 4, Epoch 21/30
# Train Loss: 1.9717
# Val Loss:   2.8839
# ----------------------------------------
# Validation improved. Model saved.
# Fold 4, Epoch 22/30
# Train Loss: 1.9156
# Val Loss:   2.8914
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 4, Epoch 23/30
# Train Loss: 1.8584
# Val Loss:   2.8836
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 4, Epoch 24/30
# Train Loss: 1.8042
# Val Loss:   2.8875
# ----------------------------------------
# No improvement for 3/3 epochs.
# Early stopping triggered.
# Best validation loss for fold 4: 2.8839
# ================================================================================
# Fold 5/5
# ================================================================================
# Train examples: 16000
# Val examples:   4000
# Fold 5, Epoch 1/30
# Train Loss: 6.0548
# Val Loss:   4.8047
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 2/30
# Train Loss: 4.4554
# Val Loss:   4.1584
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 3/30
# Train Loss: 3.9729
# Val Loss:   3.8370
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 4/30
# Train Loss: 3.6835
# Val Loss:   3.6432
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 5/30
# Train Loss: 3.4723
# Val Loss:   3.4958
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 6/30
# Train Loss: 3.2980
# Val Loss:   3.3928
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 7/30
# Train Loss: 3.1467
# Val Loss:   3.2870
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 8/30
# Train Loss: 3.0145
# Val Loss:   3.2138
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 9/30
# Train Loss: 2.8962
# Val Loss:   3.1399
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 10/30
# Train Loss: 2.7850
# Val Loss:   3.0835
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 11/30
# Train Loss: 2.6834
# Val Loss:   3.0408
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 12/30
# Train Loss: 2.5865
# Val Loss:   2.9975
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 13/30
# Train Loss: 2.4981
# Val Loss:   2.9664
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 14/30
# Train Loss: 2.4097
# Val Loss:   2.9404
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 15/30
# Train Loss: 2.3299
# Val Loss:   2.9145
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 16/30
# Train Loss: 2.2538
# Val Loss:   2.8854
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 17/30
# Train Loss: 2.1780
# Val Loss:   2.8735
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 18/30
# Train Loss: 2.1082
# Val Loss:   2.8521
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 19/30
# Train Loss: 2.0390
# Val Loss:   2.8455
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 5, Epoch 20/30
# Train Loss: 1.9740
# Val Loss:   2.8426
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 5, Epoch 21/30
# Train Loss: 1.9133
# Val Loss:   2.8255
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 22/30
# Train Loss: 1.8525
# Val Loss:   2.8123
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 23/30
# Train Loss: 1.7958
# Val Loss:   2.8031
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 5, Epoch 24/30
# Train Loss: 1.7385
# Val Loss:   2.7962
# ----------------------------------------
# Validation improved. Model saved.
# Fold 5, Epoch 25/30
# Train Loss: 1.6865
# Val Loss:   2.8067
# ----------------------------------------
# No improvement for 1/3 epochs.
# Fold 5, Epoch 26/30
# Train Loss: 1.6380
# Val Loss:   2.8006
# ----------------------------------------
# No improvement for 2/3 epochs.
# Fold 5, Epoch 27/30
# Train Loss: 1.5864
# Val Loss:   2.7908
# ----------------------------------------
# No improvement for 3/3 epochs.
# Early stopping triggered.
# Best validation loss for fold 5: 2.7962

# %%
print("=" * 80)
print("K-Fold Validation Results")
print("=" * 80)

for fold, loss in enumerate(fold_results):
    print(f"Fold {fold + 1}: Best Val Loss = {loss:.4f}")

mean_loss = np.mean(fold_results)
std_loss = np.std(fold_results)

print("-" * 40)
print(f"Average Validation Loss: {mean_loss:.4f}")
print(f"Standard Deviation:      {std_loss:.4f}")
# Out:
# ================================================================================
# K-Fold Validation Results
# ================================================================================
# Fold 1: Best Val Loss = 2.8111
# Fold 2: Best Val Loss = 2.9871
# Fold 3: Best Val Loss = 2.9284
# Fold 4: Best Val Loss = 2.8839
# Fold 5: Best Val Loss = 2.7962
# ----------------------------------------
# Average Validation Loss: 2.8814
# Standard Deviation:      0.0715

# %%
full_dataset = raw_dataset["train"].shuffle(seed=seed)

# Use 90% training, 10% validation
full_split = full_dataset.train_test_split(test_size=0.1, seed=seed)

final_train_data = full_split["train"]
final_val_data = full_split["test"]

print("Final train size:", len(final_train_data))
print("Final val size:", len(final_val_data))
# Out:
# Final train size: 114376
# Final val size: 12709

# %%
final_train_dataset = TranslationDataset(
    final_train_data,
    tokenizer,
    max_length=max_seq_length
)

final_val_dataset = TranslationDataset(
    final_val_data,
    tokenizer,
    max_length=max_seq_length
)

final_train_loader = DataLoader(
    final_train_dataset,
    batch_size=batch_size,
    shuffle=True,
    num_workers=2,
    pin_memory=True
)

final_val_loader = DataLoader(
    final_val_dataset,
    batch_size=batch_size,
    shuffle=False,
    num_workers=2,
    pin_memory=True
)

final_model = create_model()

criterion = nn.CrossEntropyLoss(ignore_index=pad_token_id)

optimizer = optim.Adam(
    final_model.parameters(),
    lr=learning_rate,
    betas=(0.9, 0.98),
    eps=1e-9
)

best_final_val_loss = float("inf")
epochs_without_improvement = 0

final_train_losses = []
final_val_losses = []

for epoch in range(max_epochs):
    train_loss = train_one_epoch(
        final_model,
        final_train_loader,
        optimizer,
        criterion,
        device
    )

    val_loss = evaluate(
        final_model,
        final_val_loader,
        criterion,
        device
    )

    final_train_losses.append(train_loss)
    final_val_losses.append(val_loss)

    print(f"Final Model Epoch {epoch + 1}/{max_epochs}")
    print(f"Train Loss: {train_loss:.4f}")
    print(f"Val Loss:   {val_loss:.4f}")
    print("-" * 40)

    if val_loss < best_final_val_loss - min_delta:
        best_final_val_loss = val_loss
        epochs_without_improvement = 0

        torch.save(
            final_model.state_dict(),
            "best_final_transformer_opus_books.pth"
        )

        print("Validation improved. Final model saved.")
    else:
        epochs_without_improvement += 1
        print(
            f"No improvement for {epochs_without_improvement}/"
            f"{patience} epochs."
        )

    if epochs_without_improvement >= patience:
        print("Early stopping triggered for final model.")
        break
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:1118: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)

# %%
best_final_model = create_model()

best_final_model.load_state_dict(
    torch.load(
        "best_final_transformer_opus_books.pth",
        map_location=device
    )
)

best_final_model.eval()

print("Best final model loaded.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1375/2244715857.py in <cell line: 0>()
# ----> 1 best_final_model = create_model()
#       2
#       3 best_final_model.load_state_dict(
#       4     torch.load(
#       5         "best_final_transformer_opus_books.pth",
#
# NameError: name 'create_model' is not defined

# %%
test_sentences = [
    "I am happy.",
    "I love reading books.",
    "Where are you going?",
    "This is a small transformer model.",
    "The weather is very nice today.",
    "She opened the door and looked outside.",
    "He was reading a book in the garden."
]

for sentence in test_sentences:
    translation = translate_sentence(
        sentence,
        best_final_model,
        tokenizer,
        device,
        max_length=max_seq_length
    )

    print("English:", sentence)
    print("French prediction:", translation)
    print("-" * 50)
